# %% [markdown]
# # Introducción a la limpieza de datos o Data Cleaning
#
# <img src = "limpieza.JPG" height = "600" width = "600">
#
# Es una técnica que transforma los datos sin procesar en un formato comprensible. Los datos del mundo real (datos sin procesar) siempre están incompletos y esos datos no se pueden enviar a través de modelos, ya que causarían ciertos errores. Es por eso que necesitamos preprocesar los datos antes de enviarlos a través de un modelo, pero antes de ello veremos algunas funciones que serán útiles para el procesado de datos básico.
#
# La limpieza de datos o `Data Cleaning` abarca un sin número de posbilidades para limpiar la data, ya que esta depende de las características del propio dataset, en el cual podremos encontrar diferentes maneras de limpiar dicha data, que al final estarán ligadas inclusive a las metodologías propias del programador, entre ellas podremos encontrar las siguientes maneras de hacerlo:
#
# - Renombrar columnas (pd.rename)
# - Casteo correcto de los datos (astype)
# - Aplicar funciones a diferentes columnas (apply, agg)
# - Eliminar variables irrelevantes o que no aportan información al dataset (drop)
# - Identificar valores nulos (isnull, isna)
# - Eliminar o tratar valores nulos (dropna)
# - Estandarizar variables numéricas
# - Estandarizar variables categóricas

# %% [markdown]
# # Concat
#
# El método concat nos permite unir tablas mediante filas o columnas, esto se especifíca mediante el parametro axis.
#
# - Axis = 0 ---> por por filas
# - Axis = 1 ---> por por columnas
#
# ```Python
# import pandas as pd
#
# pd.concat([dataframe_1, datafrme_2, ...], axis = 0) # por filas
# pd.concat([dataframe_1, datafrme_2, ...], axis = 1) # por columnas
#
#
# ```
#
# <img src = "concat.png" height = "1000" width = "1000">

# %%
import pandas as pd
import numpy as np

# %%
df_enero = pd.read_excel("./datasets/Tasa_de_Cambio_Representativa_del_Mercado-_TRM.xlsx", sheet_name = "Enero")
df_febrero = pd.read_excel("./datasets/Tasa_de_Cambio_Representativa_del_Mercado-_TRM.xlsx", sheet_name = "Febrero")

# %%
df_enero["Mes"] = "Enero"
df_enero
# Out:
#        VALOR UNIDAD VIGENCIADESDE VIGENCIAHASTA    Mes
# 0   3,258.84    COP    2020-01-03    2020-01-03  Enero
# 1   3,262.05    COP    2020-01-04    2020-01-07  Enero
# 2   3,264.26    COP    2020-01-08    2020-01-08  Enero
# 3   3,254.42    COP    2020-01-09    2020-01-09  Enero
# 4   3,253.89    COP    2020-01-10    2020-01-10  Enero
# 5   3,272.62    COP    2020-01-11    2020-01-13  Enero
# 6   3,288.05    COP    2020-01-14    2020-01-14  Enero
# 7   3,278.83    COP    2020-01-15    2020-01-15  Enero
# 8   3,296.74    COP    2020-01-16    2020-01-16  Enero
# 9   3,313.40    COP    2020-01-17    2020-01-17  Enero
# 10  3,320.77    COP    2020-01-18    2020-01-21  Enero
# 11  3,347.91    COP    2020-01-22    2020-01-22  Enero
# 12  3,337.77    COP    2020-01-23    2020-01-23  Enero
# 13  3,353.76    COP    2020-01-24    2020-01-24  Enero
# 14  3,366.01    COP    2020-01-25    2020-01-27  Enero
# 15  3,398.40    COP    2020-01-28    2020-01-28  Enero
# 16  3,392.60    COP    2020-01-29    2020-01-29  Enero
# 17  3,395.10    COP    2020-01-30    2020-01-30  Enero
# 18  3,411.45    COP    2020-01-31    2020-01-31  Enero

# %%
df_concat = pd.concat([df_enero, df_febrero], axis = 0).reset_index(drop = True)
df_concat
# Out:
#        VALOR UNIDAD VIGENCIADESDE VIGENCIAHASTA    Mes
# 0   3,258.84    COP    2020-01-03    2020-01-03  Enero
# 1   3,262.05    COP    2020-01-04    2020-01-07  Enero
# 2   3,264.26    COP    2020-01-08    2020-01-08  Enero
# 3   3,254.42    COP    2020-01-09    2020-01-09  Enero
# 4   3,253.89    COP    2020-01-10    2020-01-10  Enero
# 5   3,272.62    COP    2020-01-11    2020-01-13  Enero
# 6   3,288.05    COP    2020-01-14    2020-01-14  Enero
# 7   3,278.83    COP    2020-01-15    2020-01-15  Enero
# 8   3,296.74    COP    2020-01-16    2020-01-16  Enero
# 9   3,313.40    COP    2020-01-17    2020-01-17  Enero
# 10  3,320.77    COP    2020-01-18    2020-01-21  Enero
# 11  3,347.91    COP    2020-01-22    2020-01-22  Enero
# 12  3,337.77    COP    2020-01-23    2020-01-23  Enero
# 13  3,353.76    COP    2020-01-24    2020-01-24  Enero
# 14  3,366.01    COP    2020-01-25    2020-01-27  Enero
# 15  3,398.40    COP    2020-01-28    2020-01-28  Enero
# 16  3,392.60    COP    2020-01-29    2020-01-29  Enero
# 17  3,395.10    COP    2020-01-30    2020-01-30  Enero
# 18  3,411.45    COP    2020-01-31    2020-01-31  Enero
# 19  3,423.24    COP    2020-02-01    2020-02-03    NaN
# 20  3,401.56    COP    2020-02-04    2020-02-04    NaN
# 21  3,368.87    COP    2020-02-05    2020-02-05    NaN
# 22  3,355.44    COP    2020-02-06    2020-02-06    NaN
# 23  3,378.43    COP    2020-02-07    2020-02-07    NaN
# 24  3,408.35    COP    2020-02-08    2020-02-10    NaN
# 25  3,440.96    COP    2020-02-11    2020-02-11    NaN
# 26  3,432.89    COP    2020-02-12    2020-02-12    NaN
# 27  3,394.80    COP    2020-02-13    2020-02-13    NaN
# 28  3,385.11    COP    2020-02-14    2020-02-14    NaN
# 29  3,378.29    COP    2020-02-15    2020-02-18    NaN
# 30  3,410.24    COP    2020-02-19    2020-02-19    NaN
# 31  3,400.98    COP    2020-02-20    2020-02-20    NaN
# 32  3,403.50    COP    2020-02-21    2020-02-21    NaN
# 33  3,398.05    COP    2020-02-22    2020-02-24    NaN
# 34  3,431.60    COP    2020-02-25    2020-02-25    NaN
# 35  3,425.22    COP    2020-02-26    2020-02-26    NaN
# 36  3,441.88    COP    2020-02-27    2020-02-27    NaN
# 37  3,507.11    COP    2020-02-28    2020-02-28    NaN
# 38  3,539.86    COP    2020-02-29    2020-03-02    NaN

# %%
df_concat = pd.concat([df_enero, df_febrero], axis = 0, ignore_index = True)
df_concat
# Out:
#        VALOR UNIDAD VIGENCIADESDE VIGENCIAHASTA    Mes
# 0   3,258.84    COP    2020-01-03    2020-01-03  Enero
# 1   3,262.05    COP    2020-01-04    2020-01-07  Enero
# 2   3,264.26    COP    2020-01-08    2020-01-08  Enero
# 3   3,254.42    COP    2020-01-09    2020-01-09  Enero
# 4   3,253.89    COP    2020-01-10    2020-01-10  Enero
# 5   3,272.62    COP    2020-01-11    2020-01-13  Enero
# 6   3,288.05    COP    2020-01-14    2020-01-14  Enero
# 7   3,278.83    COP    2020-01-15    2020-01-15  Enero
# 8   3,296.74    COP    2020-01-16    2020-01-16  Enero
# 9   3,313.40    COP    2020-01-17    2020-01-17  Enero
# 10  3,320.77    COP    2020-01-18    2020-01-21  Enero
# 11  3,347.91    COP    2020-01-22    2020-01-22  Enero
# 12  3,337.77    COP    2020-01-23    2020-01-23  Enero
# 13  3,353.76    COP    2020-01-24    2020-01-24  Enero
# 14  3,366.01    COP    2020-01-25    2020-01-27  Enero
# 15  3,398.40    COP    2020-01-28    2020-01-28  Enero
# 16  3,392.60    COP    2020-01-29    2020-01-29  Enero
# 17  3,395.10    COP    2020-01-30    2020-01-30  Enero
# 18  3,411.45    COP    2020-01-31    2020-01-31  Enero
# 19  3,423.24    COP    2020-02-01    2020-02-03    NaN
# 20  3,401.56    COP    2020-02-04    2020-02-04    NaN
# 21  3,368.87    COP    2020-02-05    2020-02-05    NaN
# 22  3,355.44    COP    2020-02-06    2020-02-06    NaN
# 23  3,378.43    COP    2020-02-07    2020-02-07    NaN
# 24  3,408.35    COP    2020-02-08    2020-02-10    NaN
# 25  3,440.96    COP    2020-02-11    2020-02-11    NaN
# 26  3,432.89    COP    2020-02-12    2020-02-12    NaN
# 27  3,394.80    COP    2020-02-13    2020-02-13    NaN
# 28  3,385.11    COP    2020-02-14    2020-02-14    NaN
# 29  3,378.29    COP    2020-02-15    2020-02-18    NaN
# 30  3,410.24    COP    2020-02-19    2020-02-19    NaN
# 31  3,400.98    COP    2020-02-20    2020-02-20    NaN
# 32  3,403.50    COP    2020-02-21    2020-02-21    NaN
# 33  3,398.05    COP    2020-02-22    2020-02-24    NaN
# 34  3,431.60    COP    2020-02-25    2020-02-25    NaN
# 35  3,425.22    COP    2020-02-26    2020-02-26    NaN
# 36  3,441.88    COP    2020-02-27    2020-02-27    NaN
# 37  3,507.11    COP    2020-02-28    2020-02-28    NaN
# 38  3,539.86    COP    2020-02-29    2020-03-02    NaN

# %%
df_enero
# Out:
#        VALOR UNIDAD VIGENCIADESDE VIGENCIAHASTA    Mes
# 0   3,258.84    COP    2020-01-03    2020-01-03  Enero
# 1   3,262.05    COP    2020-01-04    2020-01-07  Enero
# 2   3,264.26    COP    2020-01-08    2020-01-08  Enero
# 3   3,254.42    COP    2020-01-09    2020-01-09  Enero
# 4   3,253.89    COP    2020-01-10    2020-01-10  Enero
# 5   3,272.62    COP    2020-01-11    2020-01-13  Enero
# 6   3,288.05    COP    2020-01-14    2020-01-14  Enero
# 7   3,278.83    COP    2020-01-15    2020-01-15  Enero
# 8   3,296.74    COP    2020-01-16    2020-01-16  Enero
# 9   3,313.40    COP    2020-01-17    2020-01-17  Enero
# 10  3,320.77    COP    2020-01-18    2020-01-21  Enero
# 11  3,347.91    COP    2020-01-22    2020-01-22  Enero
# 12  3,337.77    COP    2020-01-23    2020-01-23  Enero
# 13  3,353.76    COP    2020-01-24    2020-01-24  Enero
# 14  3,366.01    COP    2020-01-25    2020-01-27  Enero
# 15  3,398.40    COP    2020-01-28    2020-01-28  Enero
# 16  3,392.60    COP    2020-01-29    2020-01-29  Enero
# 17  3,395.10    COP    2020-01-30    2020-01-30  Enero
# 18  3,411.45    COP    2020-01-31    2020-01-31  Enero

# %%
df_concat = pd.concat([df_enero, df_febrero], axis = 1)
df_concat
# Out:
#        VALOR UNIDAD VIGENCIADESDE VIGENCIAHASTA    Mes     VALOR UNIDAD  \
# 0   3,258.84    COP    2020-01-03    2020-01-03  Enero  3,423.24    COP
# 1   3,262.05    COP    2020-01-04    2020-01-07  Enero  3,401.56    COP
# 2   3,264.26    COP    2020-01-08    2020-01-08  Enero  3,368.87    COP
# 3   3,254.42    COP    2020-01-09    2020-01-09  Enero  3,355.44    COP
# 4   3,253.89    COP    2020-01-10    2020-01-10  Enero  3,378.43    COP
# 5   3,272.62    COP    2020-01-11    2020-01-13  Enero  3,408.35    COP
# 6   3,288.05    COP    2020-01-14    2020-01-14  Enero  3,440.96    COP
# 7   3,278.83    COP    2020-01-15    2020-01-15  Enero  3,432.89    COP
# 8   3,296.74    COP    2020-01-16    2020-01-16  Enero  3,394.80    COP
# 9   3,313.40    COP    2020-01-17    2020-01-17  Enero  3,385.11    COP
# 10  3,320.77    COP    2020-01-18    2020-01-21  Enero  3,378.29    COP
# 11  3,347.91    COP    2020-01-22    2020-01-22  Enero  3,410.24    COP
# 12  3,337.77    COP    2020-01-23    2020-01-23  Enero  3,400.98    COP
# 13  3,353.76    COP    2020-01-24    2020-01-24  Enero  3,403.50    COP
# 14  3,366.01    COP    2020-01-25    2020-01-27  Enero  3,398.05    COP
# 15  3,398.40    COP    2020-01-28    2020-01-28  Enero  3,431.60    COP
# 16  3,392.60    COP    2020-01-29    2020-01-29  Enero  3,425.22    COP
# 17  3,395.10    COP    2020-01-30    2020-01-30  Enero  3,441.88    COP
# 18  3,411.45    COP    2020-01-31    2020-01-31  Enero  3,507.11    COP
# 19       NaN    NaN           NaT           NaT    NaN  3,539.86    COP
#
#    VIGENCIADESDE VIGENCIAHASTA
# 0     2020-02-01    2020-02-03
# 1     2020-02-04    2020-02-04
# 2     2020-02-05    2020-02-05
# 3     2020-02-06    2020-02-06
# 4     2020-02-07    2020-02-07
# 5     2020-02-08    2020-02-10
# 6     2020-02-11    2020-02-11
# 7     2020-02-12    2020-02-12
# 8     2020-02-13    2020-02-13
# 9     2020-02-14    2020-02-14
# 10    2020-02-15    2020-02-18
# 11    2020-02-19    2020-02-19
# 12    2020-02-20    2020-02-20
# 13    2020-02-21    2020-02-21
# 14    2020-02-22    2020-02-24
# 15    2020-02-25    2020-02-25
# 16    2020-02-26    2020-02-26
# 17    2020-02-27    2020-02-27
# 18    2020-02-28    2020-02-28
# 19    2020-02-29    2020-03-02

# %% [markdown]
# # Groupby
#
# El `groupby` en python permite agrupar datos a los cuales se les aplicará una determinada función o cálculo como vemos a continuación:
#
# <img src="groupby.png" height = "900" width = "900">

# %%
df_auto = pd.read_csv("./datasets/Automobile_data.csv", na_values = "?")
df_auto.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0      111.0
# 1          130         mpfi  3.47    2.68               9.0      111.0
# 2          152         mpfi  2.68    3.47               9.0      154.0
# 3          109         mpfi  3.19    3.40              10.0      102.0
# 4          136         mpfi  3.19    3.40               8.0      115.0
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  13495.0
# 1    5000.0       21           27  16500.0
# 2    5000.0       19           26  16500.0
# 3    5500.0       24           30  13950.0
# 4    5500.0       18           22  17450.0
#
# [5 rows x 26 columns]

# %%
df_auto.groupby(["make", "fuel-type"])["horsepower"].mean()
# Out:
# make           fuel-type
# alfa-romero    gas          125.333333
# audi           gas          121.000000
# bmw            gas          138.875000
# chevrolet      gas           62.666667
# dodge          gas           86.333333
# honda          gas           80.230769
# isuzu          gas           77.000000
# jaguar         gas          204.666667
# mazda          diesel        68.000000
#                gas           87.866667
# mercedes-benz  diesel       123.000000
#                gas          169.500000
# mercury        gas          175.000000
# mitsubishi     gas          104.076923
# nissan         diesel        55.000000
#                gas          105.352941
# peugot         diesel        95.000000
#                gas          103.833333
# plymouth       gas           86.714286
# porsche        gas          210.400000
# renault        gas                 NaN
# saab           gas          126.666667
# subaru         gas           86.250000
# toyota         diesel        61.666667
#                gas           96.000000
# volkswagen     diesel        60.000000
#                gas           91.625000
# volvo          diesel       106.000000
#                gas          130.200000
# Name: horsepower, dtype: float64

# %%
df_auto.groupby(["make", "fuel-type"])[["price"]].mean().sort_values(by = "price", ascending = False).head()
# Out:
#                             price
# make          fuel-type
# mercedes-benz gas        38900.00
# jaguar        gas        34600.00
# porsche       gas        31400.50
# mercedes-benz diesel     28394.00
# bmw           gas        26118.75

# %% [markdown]
# ## Aggregation con groupby
#
# Las funciones de agregación se pueden combinar con el groupby de la siguiente forma

# %%
df_auto.groupby(["make", "fuel-type"]).agg({"price": "mean"}).head()
# Out:
#                               price
# make        fuel-type
# alfa-romero gas        15498.333333
# audi        gas        17859.166667
# bmw         gas        26118.750000
# chevrolet   gas         6007.000000
# dodge       gas         7875.444444

# %%
df_auto.groupby(["make", "fuel-type"]).agg({"price": [np.mean, np.median, np.max, np.min]}).head()
# Out:
#                               price
#                                mean   median     amax     amin
# make        fuel-type
# alfa-romero gas        15498.333333  16500.0  16500.0  13495.0
# audi        gas        17859.166667  17580.0  23875.0  13950.0
# bmw         gas        26118.750000  22835.0  41315.0  16430.0
# chevrolet   gas         6007.000000   6295.0   6575.0   5151.0
# dodge       gas         7875.444444   7609.0  12964.0   5572.0

# %%
df_g = df_auto.groupby(["make", "fuel-type"]).agg({"price": ["mean", "median", "max", "min"]})
df_g = df_g.droplevel(0, axis = 1)
df_g.head()
# Out:
#                                mean   median      max      min
# make        fuel-type
# alfa-romero gas        15498.333333  16500.0  16500.0  13495.0
# audi        gas        17859.166667  17580.0  23875.0  13950.0
# bmw         gas        26118.750000  22835.0  41315.0  16430.0
# chevrolet   gas         6007.000000   6295.0   6575.0   5151.0
# dodge       gas         7875.444444   7609.0  12964.0   5572.0

# %%
df_auto.groupby(["make", "fuel-type"]).agg({"price": ["mean", "median", "max", "min"],
                                            "horsepower": ["mean", "median", "max", "min"]}).head()
# Out:
#                               price                             horsepower  \
#                                mean   median      max      min        mean
# make        fuel-type
# alfa-romero gas        15498.333333  16500.0  16500.0  13495.0  125.333333
# audi        gas        17859.166667  17580.0  23875.0  13950.0  121.000000
# bmw         gas        26118.750000  22835.0  41315.0  16430.0  138.875000
# chevrolet   gas         6007.000000   6295.0   6575.0   5151.0   62.666667
# dodge       gas         7875.444444   7609.0  12964.0   5572.0   86.333333
#
#
#                       median    max    min
# make        fuel-type
# alfa-romero gas        111.0  154.0  111.0
# audi        gas        110.0  160.0  102.0
# bmw         gas        121.0  182.0  101.0
# chevrolet   gas         70.0   70.0   48.0
# dodge       gas         68.0  145.0   68.0

# %% [markdown]
# ## Aggregation
#
# Los métodos de agregación son útilies cuando se quiere aplicar varios cálculos al mismo tiempo, normalmente son bastante utilizados cuando se realiza un groupby

# %%
df_auto.agg({"price": ["mean", "median", "max", "min"]})
# Out:
#                price
# mean    13207.129353
# median  10295.000000
# max     45400.000000
# min      5118.000000

# %%
pd.DataFrame({
    "mean": [df_auto["price"].mean()],
    "median": [df_auto["price"].median()],
    "max": [df_auto["price"].max()],
    "min": [df_auto["price"].min()]
}).T.rename(columns = {0: "price"})
# Out:
#                price
# mean    13207.129353
# median  10295.000000
# max     45400.000000
# min      5118.000000

# %% [markdown]
# # Valores nulos
#
# Uno de los problemas más habituales con el que podemos encontrarnos a la hora de trabajar con un conjunto de datos es la existencia de registros con valores nulos. Pudiendo ser necesario imputar un valor a estos registros para poder usarlos en un posterior análisis.
#
# Existen muchas formas de hacerlo, a continuación veremos algunos método básicos

# %%
df_erc = pd.read_csv("./datasets/erc_Data.txt", encoding = "latin1", sep = "|", na_values = "?")
df_erc.head()
# Out:
#        id Ind_ERC Ind_Ant_Fam_DM Ind_Ant_Fam_Enf_Cardio Ind_Ant_Fam_ERC  \
# 0  123391      Si             No                     No              Si
# 1   44515      No             No                     No              No
# 2  225004      Si             No                     No              No
# 3  393421      No             No                     No              No
# 4  103672      No             No                     No              No
#
#    Dias_DM  Dias_HTA Ind_Ant_Per_Anemia Ind_Ant_Per_AR Ind_Ant_Per_Dislip  \
# 0        0      3709                 No             No                 Si
# 1        0         0                 No             No                 No
# 2        0      1420                 No             No                 No
# 3        0      3776                 No             Si                 No
# 4        0         0                 No             No                 No
#
#    ... Valor_HbA1c  Valor_IMC Valor_PAD Valor_PAS Valor_PCR   Valor_TFG  \
# 0  ...         NaN  19.909972      70.0     110.0       NaN   51.625386
# 1  ...         NaN  31.833910      60.0     100.0       NaN         NaN
# 2  ...         NaN  23.108435      80.0     140.0       NaN         NaN
# 3  ...        5.44  27.303438      80.0     120.0      0.05  133.804060
# 4  ...         NaN  22.632591      60.0     100.0       NaN         NaN
#
#   Valor_Trigliceridos Edad                        Raza_Desc Sexo_Cd
# 0                62.0   68                          MESTIZO       M
# 1               171.2   49  SIN INFORMACION DESDE LA FUENTE       M
# 2                56.0   96                           BLANCO       M
# 3               112.0   93                           BLANCO       F
# 4                 NaN   57  SIN INFORMACION DESDE LA FUENTE       F
#
# [5 rows x 47 columns]

# %%
df_erc.shape[0]
# Out:
# 262331

# %% [markdown]
# ## Isnull() e Isna()

# %%
df = pd.DataFrame(df_erc.isnull().sum()).rename(columns = {0: "count_null"})
df["count_null_porcentage"] = (df["count_null"]/df_erc.shape[0])*100
df.T
# Out:
#                         id  Ind_ERC  Ind_Ant_Fam_DM  Ind_Ant_Fam_Enf_Cardio  \
# count_null             0.0      0.0             0.0                     0.0
# count_null_porcentage  0.0      0.0             0.0                     0.0
#
#                        Ind_Ant_Fam_ERC  Dias_DM  Dias_HTA  Ind_Ant_Per_Anemia  \
# count_null                         0.0      0.0       0.0                 0.0
# count_null_porcentage              0.0      0.0       0.0                 0.0
#
#                        Ind_Ant_Per_AR  Ind_Ant_Per_Dislip  ...    Valor_HbA1c  \
# count_null                        0.0                 0.0  ...  229150.000000
# count_null_porcentage             0.0                 0.0  ...      87.351476
#
#                           Valor_IMC  Valor_PAD    Valor_PAS     Valor_PCR  \
# count_null             31008.000000  25614.000  25605.00000  242712.00000
# count_null_porcentage     11.820181      9.764      9.76057      92.52128
#
#                            Valor_TFG  Valor_Trigliceridos  Edad  Raza_Desc  \
# count_null             185910.000000        158305.000000   0.0        0.0
# count_null_porcentage      70.868483            60.345518   0.0        0.0
#
#                        Sexo_Cd
# count_null                 0.0
# count_null_porcentage      0.0
#
# [2 rows x 47 columns]

# %% [markdown]
# ## Reemplzar valores nulos con fillna()
#
# Una de las formas mas efectivas de eliminar datos nulos es reemplazandolos por un calculo matemático o por el comportamiento de los datos
#
# - Especificar el valor exacto
# - Especificar un calculo estadistico
# - Utilizar bfill o ffill
#
# <img src="fillna.png" height = "580" width = "580">

# %%
df_erc["Valor_IMC"] = df_erc["Valor_IMC"].fillna(0)

# %%
import seaborn as sns

# %%
sns.histplot(df_erc["Valor_IMC"])
# Out:
# <AxesSubplot:xlabel='Valor_IMC', ylabel='Count'>

# %%
(df_erc["Valor_IMC"].std()/abs(df_erc["Valor_IMC"].mean()))*100
# Out:
# 17.78545827880948

# %%
df_erc["Valor_IMC"] = df_erc["Valor_IMC"].fillna(df_erc["Valor_IMC"].median())

# %%
df_erc["Valor_IMC"].mean()
# Out:
# 26.046052737030013

# %%
sns.histplot(df_erc["Valor_IMC"])
# Out:
# <AxesSubplot:xlabel='Valor_IMC', ylabel='Count'>

# %%
df = pd.DataFrame(df_erc.isnull().sum()).rename(columns = {0: "count_null"})
df["count_null_porcentage"] = (df["count_null"]/df_erc.shape[0])*100
df.T
# Out:
#                         id  Ind_ERC  Ind_Ant_Fam_DM  Ind_Ant_Fam_Enf_Cardio  \
# count_null             0.0      0.0             0.0                     0.0
# count_null_porcentage  0.0      0.0             0.0                     0.0
#
#                        Ind_Ant_Fam_ERC  Dias_DM  Dias_HTA  Ind_Ant_Per_Anemia  \
# count_null                         0.0      0.0       0.0                 0.0
# count_null_porcentage              0.0      0.0       0.0                 0.0
#
#                        Ind_Ant_Per_AR  Ind_Ant_Per_Dislip  ...    Valor_HbA1c  \
# count_null                        0.0                 0.0  ...  229150.000000
# count_null_porcentage             0.0                 0.0  ...      87.351476
#
#                        Valor_IMC  Valor_PAD    Valor_PAS     Valor_PCR  \
# count_null                   0.0  25614.000  25605.00000  242712.00000
# count_null_porcentage        0.0      9.764      9.76057      92.52128
#
#                            Valor_TFG  Valor_Trigliceridos  Edad  Raza_Desc  \
# count_null             185910.000000        158305.000000   0.0        0.0
# count_null_porcentage      70.868483            60.345518   0.0        0.0
#
#                        Sexo_Cd
# count_null                 0.0
# count_null_porcentage      0.0
#
# [2 rows x 47 columns]

# %% [markdown]
# ## Eliminar filas con datos nulos
#
# Una de las formas en las que podemos eliminar datos nulos es eliminando directamente todos las filas que contengan datos nulos
#
# <img src="dropna.png" height = "580" width = "580">

# %%
df_erc = pd.read_csv("./datasets/erc_Data.txt", encoding = "latin1", sep = "|", na_values = "?")
df_erc.head()
# Out:
#        id Ind_ERC Ind_Ant_Fam_DM Ind_Ant_Fam_Enf_Cardio Ind_Ant_Fam_ERC  \
# 0  123391      Si             No                     No              Si
# 1   44515      No             No                     No              No
# 2  225004      Si             No                     No              No
# 3  393421      No             No                     No              No
# 4  103672      No             No                     No              No
#
#    Dias_DM  Dias_HTA Ind_Ant_Per_Anemia Ind_Ant_Per_AR Ind_Ant_Per_Dislip  \
# 0        0      3709                 No             No                 Si
# 1        0         0                 No             No                 No
# 2        0      1420                 No             No                 No
# 3        0      3776                 No             Si                 No
# 4        0         0                 No             No                 No
#
#    ... Valor_HbA1c  Valor_IMC Valor_PAD Valor_PAS Valor_PCR   Valor_TFG  \
# 0  ...         NaN  19.909972      70.0     110.0       NaN   51.625386
# 1  ...         NaN  31.833910      60.0     100.0       NaN         NaN
# 2  ...         NaN  23.108435      80.0     140.0       NaN         NaN
# 3  ...        5.44  27.303438      80.0     120.0      0.05  133.804060
# 4  ...         NaN  22.632591      60.0     100.0       NaN         NaN
#
#   Valor_Trigliceridos Edad                        Raza_Desc Sexo_Cd
# 0                62.0   68                          MESTIZO       M
# 1               171.2   49  SIN INFORMACION DESDE LA FUENTE       M
# 2                56.0   96                           BLANCO       M
# 3               112.0   93                           BLANCO       F
# 4                 NaN   57  SIN INFORMACION DESDE LA FUENTE       F
#
# [5 rows x 47 columns]

# %%
df_erc = df_erc.dropna(subset = ["Valor_IMC"], axis = 0)

# %%
df = pd.DataFrame(df_erc.isnull().sum()).rename(columns = {0: "count_null"})
df["count_null_porcentage"] = (df["count_null"]/df_erc.shape[0])*100
df.T
# Out:
#                         id  Ind_ERC  Ind_Ant_Fam_DM  Ind_Ant_Fam_Enf_Cardio  \
# count_null             0.0      0.0             0.0                     0.0
# count_null_porcentage  0.0      0.0             0.0                     0.0
#
#                        Ind_Ant_Fam_ERC  Dias_DM  Dias_HTA  Ind_Ant_Per_Anemia  \
# count_null                         0.0      0.0       0.0                 0.0
# count_null_porcentage              0.0      0.0       0.0                 0.0
#
#                        Ind_Ant_Per_AR  Ind_Ant_Per_Dislip  ...    Valor_HbA1c  \
# count_null                        0.0                 0.0  ...  199573.000000
# count_null_porcentage             0.0                 0.0  ...      86.274603
#
#                        Valor_IMC    Valor_PAD    Valor_PAS      Valor_PCR  \
# count_null                   0.0  5145.000000  5143.000000  212968.000000
# count_null_porcentage        0.0     2.224163     2.223298      92.065208
#
#                            Valor_TFG  Valor_Trigliceridos  Edad  Raza_Desc  \
# count_null             156411.000000        131502.000000   0.0        0.0
# count_null_porcentage      67.615845            56.847784   0.0        0.0
#
#                        Sexo_Cd
# count_null                 0.0
# count_null_porcentage      0.0
#
# [2 rows x 47 columns]

# %%
df_erc.shape
# Out:
# (231323, 47)

# %% [markdown]
# ## Método Replace

# %%
df_athletes = pd.read_csv("./datasets/athletes.csv")
df_athletes
# Out:
#               id                name nationality     sex       dob  height  \
# 0      736041664      A Jesus Garcia         ESP    male  10/17/69    1.72
# 1      532037425          A Lam Shin         KOR  female   9/23/86    1.68
# 2      435962603         Aaron Brown         CAN    male   5/27/92    1.98
# 3      521041435          Aaron Cook         MDA    male    1/2/91    1.83
# 4       33922579          Aaron Gate         NZL    male  11/26/90    1.81
# ...          ...                 ...         ...     ...       ...     ...
# 11533  265605954  Zurian Hechavarria         CUB  female   8/10/95    1.64
# 11534  214461847      Zuzana Hejnova         CZE  female  12/19/86    1.73
# 11535   88361042             di Xiao         CHN    male   5/14/91    1.85
# 11536  900065925   le Quoc Toan Tran         VIE    male    4/5/89    1.60
# 11537  711404576      le Roux Hamman         RSA    male    1/6/92    1.85
#
#        weight          sport  gold  silver  bronze
# 0        64.0      athletics     0       0       0
# 1        56.0        fencing     0       0       0
# 2        79.0      athletics     0       0       1
# 3        80.0      taekwondo     0       0       0
# 4        71.0        cycling     0       0       0
# ...       ...            ...   ...     ...     ...
# 11533    58.0      athletics     0       0       0
# 11534    63.0      athletics     0       0       0
# 11535   100.0      wrestling     0       0       0
# 11536    56.0  weightlifting     0       0       0
# 11537    70.0      athletics     0       0       0
#
# [11538 rows x 11 columns]

# %%
df_athletes_1 = df_athletes.iloc[0:11000,:]
df_athletes_2 = df_athletes.iloc[11000:11538,:]

# %%
df_athletes_2["sex"] = None
# Out:
# C:\Users\usuario1\AppData\Local\Temp\ipykernel_10752\1442325135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_athletes_2["sex"] = None

# %%
df_athletes_c = pd.concat([df_athletes_1, df_athletes_2], axis = 0)
df_athletes_c
# Out:
#               id                name nationality     sex       dob  height  \
# 0      736041664      A Jesus Garcia         ESP    male  10/17/69    1.72
# 1      532037425          A Lam Shin         KOR  female   9/23/86    1.68
# 2      435962603         Aaron Brown         CAN    male   5/27/92    1.98
# 3      521041435          Aaron Cook         MDA    male    1/2/91    1.83
# 4       33922579          Aaron Gate         NZL    male  11/26/90    1.81
# ...          ...                 ...         ...     ...       ...     ...
# 11533  265605954  Zurian Hechavarria         CUB    None   8/10/95    1.64
# 11534  214461847      Zuzana Hejnova         CZE    None  12/19/86    1.73
# 11535   88361042             di Xiao         CHN    None   5/14/91    1.85
# 11536  900065925   le Quoc Toan Tran         VIE    None    4/5/89    1.60
# 11537  711404576      le Roux Hamman         RSA    None    1/6/92    1.85
#
#        weight          sport  gold  silver  bronze
# 0        64.0      athletics     0       0       0
# 1        56.0        fencing     0       0       0
# 2        79.0      athletics     0       0       1
# 3        80.0      taekwondo     0       0       0
# 4        71.0        cycling     0       0       0
# ...       ...            ...   ...     ...     ...
# 11533    58.0      athletics     0       0       0
# 11534    63.0      athletics     0       0       0
# 11535   100.0      wrestling     0       0       0
# 11536    56.0  weightlifting     0       0       0
# 11537    70.0      athletics     0       0       0
#
# [11538 rows x 11 columns]

# %%
def convert_sex(item):
    
    if item.split(" ")[0][-1] == "a":
        return "female"
    
    else:
         return "male"

# %%
df_athletes_c["sex_new"] = df_athletes_c["name"].apply(lambda x: convert_sex(x))

# %%
df_athletes_c
# Out:
#               id                name nationality     sex       dob  height  \
# 0      736041664      A Jesus Garcia         ESP    male  10/17/69    1.72
# 1      532037425          A Lam Shin         KOR  female   9/23/86    1.68
# 2      435962603         Aaron Brown         CAN    male   5/27/92    1.98
# 3      521041435          Aaron Cook         MDA    male    1/2/91    1.83
# 4       33922579          Aaron Gate         NZL    male  11/26/90    1.81
# ...          ...                 ...         ...     ...       ...     ...
# 11533  265605954  Zurian Hechavarria         CUB    None   8/10/95    1.64
# 11534  214461847      Zuzana Hejnova         CZE    None  12/19/86    1.73
# 11535   88361042             di Xiao         CHN    None   5/14/91    1.85
# 11536  900065925   le Quoc Toan Tran         VIE    None    4/5/89    1.60
# 11537  711404576      le Roux Hamman         RSA    None    1/6/92    1.85
#
#        weight          sport  gold  silver  bronze sex_new
# 0        64.0      athletics     0       0       0    male
# 1        56.0        fencing     0       0       0    male
# 2        79.0      athletics     0       0       1    male
# 3        80.0      taekwondo     0       0       0    male
# 4        71.0        cycling     0       0       0    male
# ...       ...            ...   ...     ...     ...     ...
# 11533    58.0      athletics     0       0       0    male
# 11534    63.0      athletics     0       0       0  female
# 11535   100.0      wrestling     0       0       0    male
# 11536    56.0  weightlifting     0       0       0    male
# 11537    70.0      athletics     0       0       0    male
#
# [11538 rows x 12 columns]
